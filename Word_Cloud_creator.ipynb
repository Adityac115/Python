# %% [markdown]
# # Word Cloud

# %%
# Here are all the installs and imports you will need for your word cloud script and uploader widget

# %pip install wordcloud
# %pip install fileupload
# %pip install ipywidgets
# %jupyter nbextension install --py --user fileupload
# %jupyter nbextension enable --py fileupload

import wordcloud
import numpy as np
from matplotlib import pyplot as plt
from IPython.display import display
import fileupload
import io
import sys
# Out:
# Requirement already satisfied: wordcloud in c:\users\aditya\appdata\local\programs\python\python311\lib\site-packages (1.8.1)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\aditya\appdata\local\programs\python\python311\lib\site-packages (from wordcloud) (1.23.5)
# Requirement already satisfied: pillow in c:\users\aditya\appdata\local\programs\python\python311\lib\site-packages (from wordcloud) (9.3.0)
# Requirement already satisfied: matplotlib in c:\users\aditya\appdata\local\programs\python\python311\lib\site-packages (from wordcloud) (3.6.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\aditya\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->wordcloud) (1.0.6)
# Requirement already satisfied: cycler>=0.10 in c:\users\aditya\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\aditya\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->wordcloud) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\aditya\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\aditya\appdata\roaming\python\python311\site-packages (from matplotlib->wordcloud) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\aditya\appdata\roaming\python\python311\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\aditya\appdata\roaming\python\python311\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\aditya\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: fileupload in c:\users\aditya\appdata\local\programs\python\python311\lib\site-packages (0.1.5)
# Requirement already satisfied: ipywidgets>=5.1 in c:\users\aditya\appdata\local\programs\python\python311\lib\site-packages (from fileupload) (8.0.4)
# Requirement already satisfied: notebook>=4.2 in c:\users\aditya\appdata\local\programs\python\python311\lib\site-packages (from fileupload) (6.5.2)
# Requirement already satisfied: traitlets>=4.2 in c:\users\aditya\appdata\roaming\python\python311\site-packages (from fileupload) (5.6.0)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\aditya\appdata\roaming\python\python311\site-packages (from ipywidgets>=5.1->fileupload) (6.17.1)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\aditya\appdata\roaming\python\python311\site-packages (from ipywidgets>=5.1->fileupload) (8.7.0)
# Requirement already satisfied: widgetsnbextension~=4.0 in c:\users\aditya\appdata\local\programs\python\python311\lib\site-packages (from ipywidgets>=5.1->fileupload) (4.0.5)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in c:\users\aditya\appdata\local\programs\python\python311\lib\site-packages (from ipywidgets>=5.1->fileupload) (3.0.5)
# Requirement already satisfied: jinja2 in c:\users\aditya\appdata\local\programs\python\python311\lib\site-packages (from notebook>=4.2->fileupload) (3.1.2)
# Requirement already satisfied: tornado>=6.1 in c:\users\aditya\appdata\roaming\python\python311\site-packages (from notebook>=4.2->fileupload) (6.2)
# Requirement already satisfied: pyzmq>=17 in c:\users\aditya\appdata\roaming\python\python311\site-packages (from notebook>=4.2->fileupload) (24.0.1)
# Requirement already satisfied: argon2-cffi in c:\users\aditya\appdata\local\programs\python\python311\lib\site-packages (from notebook>=4.2->fileupload) (21.3.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in c:\users\aditya\appdata\roaming\python\python311\site-packages (from notebook>=4.2->fileupload) (5.1.0)
# Requirement already satisfied: jupyter-client>=5.3.4 in c:\users\aditya\appdata\roaming\python\python311\site-packages (from notebook>=4.2->fileupload) (7.4.7)
# Requirement already satisfied: ipython-genutils in c:\users\aditya\appdata\local\programs\python\python311\lib\site-packages (from notebook>=4.2->fileupload) (0.2.0)
# Requirement already satisfied: nbformat in c:\users\aditya\appdata\local\programs\python\python311\lib\site-packages (from notebook>=4.2->fileupload) (5.7.1)
# Requirement already satisfied: nbconvert>=5 in c:\users\aditya\appdata\local\programs\python\python311\lib\site-packages (from notebook>=4.2->fileupload) (7.2.7)
# Requirement already satisfied: nest-asyncio>=1.5 in c:\users\aditya\appdata\roaming\python\python311\site-packages (from notebook>=4.2->fileupload) (1.5.6)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\aditya\appdata\local\programs\python\python311\lib\site-packages (from notebook>=4.2->fileupload) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\aditya\appdata\local\programs\python\python311\lib\site-packages (from notebook>=4.2->fileupload) (0.17.1)
# Requirement already satisfied: prometheus-client in c:\users\aditya\appdata\local\programs\python\python311\lib\site-packages (from notebook>=4.2->fileupload) (0.15.0)
# Requirement already satisfied: nbclassic>=0.4.7 in c:\users\aditya\appdata\local\programs\python\python311\lib\site-packages (from notebook>=4.2->fileupload) (0.4.8)
# Requirement already satisfied: debugpy>=1.0 in c:\users\aditya\appdata\roaming\python\python311\site-packages (from ipykernel>=4.5.1->ipywidgets>=5.1->fileupload) (1.6.4)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\aditya\appdata\roaming\python\python311\site-packages (from ipykernel>=4.5.1->ipywidgets>=5.1->fileupload) (0.1.6)
# Requirement already satisfied: packaging in c:\users\aditya\appdata\roaming\python\python311\site-packages (from ipykernel>=4.5.1->ipywidgets>=5.1->fileupload) (21.3)
# Requirement already satisfied: psutil in c:\users\aditya\appdata\roaming\python\python311\site-packages (from ipykernel>=4.5.1->ipywidgets>=5.1->fileupload) (5.9.4)
# Requirement already satisfied: backcall in c:\users\aditya\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets>=5.1->fileupload) (0.2.0)
# Requirement already satisfied: decorator in c:\users\aditya\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets>=5.1->fileupload) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\aditya\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets>=5.1->fileupload) (0.18.2)
# Requirement already satisfied: pickleshare in c:\users\aditya\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets>=5.1->fileupload) (0.7.5)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.11 in c:\users\aditya\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets>=5.1->fileupload) (3.0.33)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\aditya\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets>=5.1->fileupload) (2.13.0)
# Requirement already satisfied: stack-data in c:\users\aditya\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets>=5.1->fileupload) (0.6.2)
# Requirement already satisfied: colorama in c:\users\aditya\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets>=5.1->fileupload) (0.4.6)
# Requirement already satisfied: entrypoints in c:\users\aditya\appdata\roaming\python\python311\site-packages (from jupyter-client>=5.3.4->notebook>=4.2->fileupload) (0.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\aditya\appdata\roaming\python\python311\site-packages (from jupyter-client>=5.3.4->notebook>=4.2->fileupload) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\aditya\appdata\roaming\python\python311\site-packages (from jupyter-core>=4.6.1->notebook>=4.2->fileupload) (2.5.4)
# Requirement already satisfied: pywin32>=1.0 in c:\users\aditya\appdata\roaming\python\python311\site-packages (from jupyter-core>=4.6.1->notebook>=4.2->fileupload) (305)
# Requirement already satisfied: jupyter-server>=1.8 in c:\users\aditya\appdata\local\programs\python\python311\lib\site-packages (from nbclassic>=0.4.7->notebook>=4.2->fileupload) (2.0.5)
# Requirement already satisfied: notebook-shim>=0.1.0 in c:\users\aditya\appdata\local\programs\python\python311\lib\site-packages (from nbclassic>=0.4.7->notebook>=4.2->fileupload) (0.2.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\aditya\appdata\local\programs\python\python311\lib\site-packages (from nbconvert>=5->notebook>=4.2->fileupload) (4.11.1)
# Requirement already satisfied: bleach in c:\users\aditya\appdata\local\programs\python\python311\lib\site-packages (from nbconvert>=5->notebook>=4.2->fileupload) (5.0.1)
# Requirement already satisfied: defusedxml in c:\users\aditya\appdata\local\programs\python\python311\lib\site-packages (from nbconvert>=5->notebook>=4.2->fileupload) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\aditya\appdata\local\programs\python\python311\lib\site-packages (from nbconvert>=5->notebook>=4.2->fileupload) (0.2.2)
# Requirement already satisfied: markupsafe>=2.0 in c:\users\aditya\appdata\local\programs\python\python311\lib\site-packages (from nbconvert>=5->notebook>=4.2->fileupload) (2.1.1)
# Requirement already satisfied: mistune<3,>=2.0.3 in c:\users\aditya\appdata\local\programs\python\python311\lib\site-packages (from nbconvert>=5->notebook>=4.2->fileupload) (2.0.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\aditya\appdata\local\programs\python\python311\lib\site-packages (from nbconvert>=5->notebook>=4.2->fileupload) (0.7.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\aditya\appdata\local\programs\python\python311\lib\site-packages (from nbconvert>=5->notebook>=4.2->fileupload) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\users\aditya\appdata\local\programs\python\python311\lib\site-packages (from nbconvert>=5->notebook>=4.2->fileupload) (1.2.1)
# Requirement already satisfied: fastjsonschema in c:\users\aditya\appdata\local\programs\python\python311\lib\site-packages (from nbformat->notebook>=4.2->fileupload) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\aditya\appdata\local\programs\python\python311\lib\site-packages (from nbformat->notebook>=4.2->fileupload) (4.17.3)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\aditya\appdata\local\programs\python\python311\lib\site-packages (from terminado>=0.8.3->notebook>=4.2->fileupload) (2.0.9)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\aditya\appdata\local\programs\python\python311\lib\site-packages (from argon2-cffi->notebook>=4.2->fileupload) (21.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\aditya\appdata\roaming\python\python311\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=5.1->fileupload) (0.8.3)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\aditya\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=2.6->nbformat->notebook>=4.2->fileupload) (22.2.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\aditya\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=2.6->nbformat->notebook>=4.2->fileupload) (0.19.2)
# Requirement already satisfied: anyio<4,>=3.1.0 in c:\users\aditya\appdata\local\programs\python\python311\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.2->fileupload) (3.6.2)
# Requirement already satisfied: jupyter-events>=0.4.0 in c:\users\aditya\appdata\local\programs\python\python311\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.2->fileupload) (0.5.0)
# Requirement already satisfied: jupyter-server-terminals in c:\users\aditya\appdata\local\programs\python\python311\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.2->fileupload) (0.4.3)
# Requirement already satisfied: websocket-client in c:\users\aditya\appdata\local\programs\python\python311\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.2->fileupload) (1.4.2)
# Requirement already satisfied: wcwidth in c:\users\aditya\appdata\roaming\python\python311\site-packages (from prompt-toolkit<3.1.0,>=3.0.11->ipython>=6.1.0->ipywidgets>=5.1->fileupload) (0.2.5)
# Requirement already satisfied: six>=1.5 in c:\users\aditya\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.8.2->jupyter-client>=5.3.4->notebook>=4.2->fileupload) (1.16.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\aditya\appdata\local\programs\python\python311\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.2->fileupload) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\aditya\appdata\local\programs\python\python311\lib\site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.2->fileupload) (2.3.2.post1)
# Requirement already satisfied: webencodings in c:\users\aditya\appdata\local\programs\python\python311\lib\site-packages (from bleach->nbconvert>=5->notebook>=4.2->fileupload) (0.5.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\aditya\appdata\roaming\python\python311\site-packages (from packaging->ipykernel>=4.5.1->ipywidgets>=5.1->fileupload) (3.0.9)
# Requirement already satisfied: executing>=1.2.0 in c:\users\aditya\appdata\roaming\python\python311\site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=5.1->fileupload) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\aditya\appdata\roaming\python\python311\site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=5.1->fileupload) (2.2.0)
# Requirement already satisfied: pure-eval in c:\users\aditya\appdata\roaming\python\python311\site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=5.1->fileupload) (0.2.2)
# Requirement already satisfied: idna>=2.8 in c:\users\aditya\appdata\local\programs\python\python311\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.2->fileupload) (3.4)
# Requirement already satisfied: sniffio>=1.1 in c:\users\aditya\appdata\local\programs\python\python311\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.2->fileupload) (1.3.0)
# Requirement already satisfied: pycparser in c:\users\aditya\appdata\local\programs\python\python311\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.2->fileupload) (2.21)
# Requirement already satisfied: python-json-logger in c:\users\aditya\appdata\local\programs\python\python311\lib\site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.2->fileupload) (2.0.4)
# Requirement already satisfied: pyyaml in c:\users\aditya\appdata\local\programs\python\python311\lib\site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.2->fileupload) (6.0)
# Requirement already satisfied: fqdn in c:\users\aditya\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=2.6->nbformat->notebook>=4.2->fileupload) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\aditya\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=2.6->nbformat->notebook>=4.2->fileupload) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\aditya\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=2.6->nbformat->notebook>=4.2->fileupload) (2.3)
# Requirement already satisfied: rfc3339-validator in c:\users\aditya\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=2.6->nbformat->notebook>=4.2->fileupload) (0.1.4)
# Requirement already satisfied: rfc3986-validator>0.1.0 in c:\users\aditya\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=2.6->nbformat->notebook>=4.2->fileupload) (0.1.1)
# Requirement already satisfied: uri-template in c:\users\aditya\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=2.6->nbformat->notebook>=4.2->fileupload) (1.2.0)
# Requirement already satisfied: webcolors>=1.11 in c:\users\aditya\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=2.6->nbformat->notebook>=4.2->fileupload) (1.12)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\aditya\appdata\local\programs\python\python311\lib\site-packages (from isoduration->jsonschema>=2.6->nbformat->notebook>=4.2->fileupload) (1.2.3)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: ipywidgets in c:\users\aditya\appdata\local\programs\python\python311\lib\site-packages (8.0.4)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\aditya\appdata\roaming\python\python311\site-packages (from ipywidgets) (6.17.1)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\aditya\appdata\roaming\python\python311\site-packages (from ipywidgets) (8.7.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\aditya\appdata\roaming\python\python311\site-packages (from ipywidgets) (5.6.0)
# Requirement already satisfied: widgetsnbextension~=4.0 in c:\users\aditya\appdata\local\programs\python\python311\lib\site-packages (from ipywidgets) (4.0.5)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in c:\users\aditya\appdata\local\programs\python\python311\lib\site-packages (from ipywidgets) (3.0.5)
# Requirement already satisfied: debugpy>=1.0 in c:\users\aditya\appdata\roaming\python\python311\site-packages (from ipykernel>=4.5.1->ipywidgets) (1.6.4)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\aditya\appdata\roaming\python\python311\site-packages (from ipykernel>=4.5.1->ipywidgets) (7.4.7)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\aditya\appdata\roaming\python\python311\site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.6)
# Requirement already satisfied: nest-asyncio in c:\users\aditya\appdata\roaming\python\python311\site-packages (from ipykernel>=4.5.1->ipywidgets) (1.5.6)
# Requirement already satisfied: packaging in c:\users\aditya\appdata\roaming\python\python311\site-packages (from ipykernel>=4.5.1->ipywidgets) (21.3)
# Requirement already satisfied: psutil in c:\users\aditya\appdata\roaming\python\python311\site-packages (from ipykernel>=4.5.1->ipywidgets) (5.9.4)
# Requirement already satisfied: pyzmq>=17 in c:\users\aditya\appdata\roaming\python\python311\site-packages (from ipykernel>=4.5.1->ipywidgets) (24.0.1)
# Requirement already satisfied: tornado>=6.1 in c:\users\aditya\appdata\roaming\python\python311\site-packages (from ipykernel>=4.5.1->ipywidgets) (6.2)
# Requirement already satisfied: backcall in c:\users\aditya\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: decorator in c:\users\aditya\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\aditya\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets) (0.18.2)
# Requirement already satisfied: pickleshare in c:\users\aditya\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets) (0.7.5)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.11 in c:\users\aditya\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.33)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\aditya\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets) (2.13.0)
# Requirement already satisfied: stack-data in c:\users\aditya\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets) (0.6.2)
# Requirement already satisfied: colorama in c:\users\aditya\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\aditya\appdata\roaming\python\python311\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: entrypoints in c:\users\aditya\appdata\roaming\python\python311\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (0.4)
# Requirement already satisfied: jupyter-core>=4.9.2 in c:\users\aditya\appdata\roaming\python\python311\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (5.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\aditya\appdata\roaming\python\python311\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (2.8.2)
# Requirement already satisfied: wcwidth in c:\users\aditya\appdata\roaming\python\python311\site-packages (from prompt-toolkit<3.1.0,>=3.0.11->ipython>=6.1.0->ipywidgets) (0.2.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\aditya\appdata\roaming\python\python311\site-packages (from packaging->ipykernel>=4.5.1->ipywidgets) (3.0.9)
# Requirement already satisfied: executing>=1.2.0 in c:\users\aditya\appdata\roaming\python\python311\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\aditya\appdata\roaming\python\python311\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.2.0)
# Requirement already satisfied: pure-eval in c:\users\aditya\appdata\roaming\python\python311\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: six in c:\users\aditya\appdata\roaming\python\python311\site-packages (from asttokens>=2.1.0->stack-data->ipython>=6.1.0->ipywidgets) (1.16.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\aditya\appdata\roaming\python\python311\site-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (2.5.4)
# Requirement already satisfied: pywin32>=1.0 in c:\users\aditya\appdata\roaming\python\python311\site-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (305)
# Note: you may need to restart the kernel to use updated packages.

# %%
# This is the uploader widget

def _upload():

    _upload_widget = fileupload.FileUploadWidget()

    def _cb(change):
        global file_contents
        decoded = io.StringIO(change['owner'].data.decode('utf-8'))
        filename = change['owner'].filename
        print('Uploaded `{}` ({:.2f} kB)'.format(
            filename, len(decoded.read()) / 2 **10))
        file_contents = decoded.getvalue()

    _upload_widget.observe(_cb, names='data')
    display(_upload_widget)

_upload()
# Out:
# FileUploadWidget(label='Browse', _dom_classes=('widget_item', 'btn-group'))
# Uploaded `novel.txt` (125.40 kB)

# %%
def calculate_frequencies(file_contents):
    # Here is a list of punctuations and uninteresting words you can use to process your text
    punctuations = '''!()-[]{};:'"\,<>./?@#$%^&*_~'''
    uninteresting_words = ["the", "a", "to", "if", "is", "it", "of", "and", "or", "an", "as", "i", "me", "my", \
    "we", "our", "ours", "you", "your", "yours", "he", "she", "him", "his", "her", "hers", "its", "they", "them", \
    "their", "what", "which", "who", "whom", "this", "that", "am", "are", "was", "were", "be", "been", "being", \
    "have", "has", "had", "do", "does", "did", "but", "at", "by", "with", "from", "here", "when", "where", "how", \
    "all", "any", "both", "each", "few", "more", "some", "such", "no", "nor", "too", "very", "can", "will", "just","not",\
                          "in","so"]
    
    # LEARNER CODE START HERE
    text_need=""
    frequency_count={}
    for char in file_contents:
        if char not in punctuations:
            text_need+=char
            
    word_list=text_need.split()
    
    
    for word in word_list:
        if word.lower() not in uninteresting_words:
            if word in frequency_count:
                frequency_count[word]+=1
            else:
                frequency_count[word]=1
    #wordcloud
    cloud = wordcloud.WordCloud()
    cloud.generate_from_frequencies(frequency_count)
    return cloud.to_array()

# %%
# Display your wordcloud image

myimage = calculate_frequencies(file_contents)
plt.imshow(myimage, interpolation = 'nearest')
plt.axis('off')
plt.show()

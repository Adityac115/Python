# %%
f=["a","b","c","d","e"]

# %%
f[::-1]
# Out:
# ['e', 'd', 'c', 'b', 'a']

# %%
s="aditya"
s[::-1]
# Out:
# 'aytida'

# %%
s="nitin"
s[::-1]
# Out:
# 'nitin'

# %%
s="my name is aditya"
"aditya" in s
# Out:
# True

# %%
for i in range(50):
    print("hi")
# Out:
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi

# %%
n=0
while (n!=50):
    print("hi")
    n=n+1
# Out:
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi

# %%
import pywhatkit
